# %%
import geopandas as gpd

# %%
import matplotlib.pyplot as plt

# %%
delitos = "Delitos_Alto_Impacto_Localidad.geojson"
map_data = gpd.read_file(delitos)
map_data.head()
# Out:
#   CMIULOCAL                                           geometry
# 0        20  POLYGON ((-74.20584 4.26966, -74.20567 4.26952...
# 1        18  POLYGON ((-74.12803 4.59254, -74.12829 4.59265...
# 2        17  POLYGON ((-74.06621 4.60317, -74.06621 4.60317...
# 3        12  POLYGON ((-74.05725 4.68684, -74.05725 4.68684...
# 4        13  POLYGON ((-74.09372 4.66607, -74.10342 4.65351...

# %%
map_data.plot()
# Out:
# <AxesSubplot:>

# %%
DELITOS = "DAILoc.shp"
map_BO = gpd.read_file(DELITOS)
map_BO.head()
# Out:
#   CMIULOCAL          CMNOMLOCAL    CMMES  CMH18CONT  CMH19CONT  CMH20CONT  \
# 0        18  Rafael Uribe Uribe  Ene-Dic       70.0       61.0       86.0
# 1        17          Candelaria  Ene-Dic        3.0        2.0        3.0
# 2        12      Barrios Unidos  Ene-Dic       12.0        9.0        9.0
# 3        13         Teusaquillo  Ene-Dic        6.0        4.0        5.0
# 4        16       Puente Aranda  Ene-Dic       26.0       35.0       45.0
#
#    CMHVAR  CMHTOTAL  CMLP18CONT  CMLP19CONT  ...  CMHB21CONT  CMHCE21CON  \
# 0   -2.33    1128.0      1601.0      1483.0  ...       216.0      2216.0
# 1  100.00    1128.0       242.0       266.0  ...        36.0       452.0
# 2   22.22    1128.0       751.0       565.0  ...       423.0      2063.0
# 3  200.00    1128.0       743.0       421.0  ...       469.0      2637.0
# 4  -60.00    1128.0      1249.0       986.0  ...       409.0      2775.0
#
#    CMHM21CONT  CMHF21CONT  CMHC21CONT  CMDS21CONT  CMVI21CONT  SHAPE_AREA  \
# ...

# %%
map_BO
# Out:
#    CMIULOCAL          CMNOMLOCAL    CMMES  CMH18CONT  CMH19CONT  CMH20CONT  \
# 0         18  Rafael Uribe Uribe  Ene-Dic       70.0       61.0       86.0
# 1         17          Candelaria  Ene-Dic        3.0        2.0        3.0
# 2         12      Barrios Unidos  Ene-Dic       12.0        9.0        9.0
# 3         13         Teusaquillo  Ene-Dic        6.0        4.0        5.0
# 4         16       Puente Aranda  Ene-Dic       26.0       35.0       45.0
# 5         14       Los MÃ¡rtires  Ene-Dic       55.0       66.0       52.0
# 6         20             Sumapaz  Ene-Dic        0.0        0.0        1.0
# 7         01            UsaquÃ©n  Ene-Dic       36.0       33.0       50.0
# 8         02           Chapinero  Ene-Dic       10.0       15.0        9.0
# 9         04      San CristÃ³bal  Ene-Dic       54.0       46.0       54.0
# 10        05                Usme  Ene-Dic       85.0       90.0       67.0
# ...

# %%
map_BO.columns
# Out:
# Index(['CMIULOCAL', 'CMNOMLOCAL', 'CMMES', 'CMH18CONT', 'CMH19CONT',
#        'CMH20CONT', 'CMHVAR', 'CMHTOTAL', 'CMLP18CONT', 'CMLP19CONT',
#        'CMLP20CONT', 'CMLPVAR', 'CMLPTOTAL', 'CMHP18CONT', 'CMHP19CONT',
#        'CMHP20CONT', 'CMHPVAR', 'CMHPTOTAL', 'CMHR18CONT', 'CMHR19CONT',
#        'CMHR20CONT', 'CMHRVAR', 'CMHRTOTAL', 'CMHA18CONT', 'CMHA19CONT',
#        'CMHA20CONT', 'CMHAVAR', 'CMHATOTAL', 'CMHB18CONT', 'CMHB19CONT',
#        'CMHB20CONT', 'CMHBVAR', 'CMHBTOTAL', 'CMHC18CONT', 'CMHC19CONT',
#        'CMHC20CONT', 'CMHCVAR', 'CMHCTOTAL', 'CMHCE18CON', 'CMHCE19CON',
#        'CMHCE20CON', 'CMHCEVAR', 'CMHCETOTAL', 'CMHM18CONT', 'CMHM19CONT',
#        'CMHM20CONT', 'CMHMVAR', 'CMHMTOTAL', 'CMHF18CONT', 'CMHF19CONT',
#        'CMHF20CONT', 'CMHFVAR', 'CMHFTOTAL', 'CMDS18CONT', 'CMDS19CONT',
#        'CMDS20CONT', 'CMDSVAR', 'CMDSTOTAL', 'CMVI18CONT', 'CMVI19CONT',
#        'CMVI20CONT', 'CMVIVAR', 'CMVITOTAL', 'CMH21CONT', 'CMLP21CONT',
# ...

# %%
# Control del tamaño de la figura del mapa
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
 
# Control del encuadre (área geográfica) del mapa
#ax.axis([-12, 5, 32, 48])
 
# Control del título y los ejes
ax.set_title('HURTO A PERSONAS  2018', 
             pad = 20, 
             fontdict={'fontsize':20, 'color': '#4873ab'})

 
# Añadir la leyenda separada del mapa
from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.2)
 
# Generar y cargar el mapa
map_BO.plot(column='CMHP18CONT', cmap='winter', ax=ax,
              legend=True, cax=cax, zorder=5)
fig.savefig('HurtoP 2018.jpg')

# %%
# Control del tamaño de la figura del mapa
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
 
# Control del encuadre (área geográfica) del mapa
#ax.axis([-12, 5, 32, 48])
 
# Control del título y los ejes
ax.set_title('HURTO A PERSONAS  2019', 
             pad = 20, 
             fontdict={'fontsize':20, 'color': '#4873ab'})

 
# Añadir la leyenda separada del mapa
from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.2)
 
# Generar y cargar el mapa
map_BO.plot(column='CMHP21CONT', cmap='winter', ax=ax,
              legend=True, cax=cax, zorder=5)
fig.savefig('HurtoP 2019.jpg')

# %%
# Control del tamaño de la figura del mapa
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
 
# Control del encuadre (área geográfica) del mapa
#ax.axis([-12, 5, 32, 48])
 
# Control del título y los ejes
ax.set_title('HURTO A PERSONAS  2020', 
             pad = 20, 
             fontdict={'fontsize':20, 'color': '#4873ab'})

 
# Añadir la leyenda separada del mapa
from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.2)
 
# Generar y cargar el mapa
map_BO.plot(column='CMHP21CONT', cmap='winter', ax=ax,
              legend=True, cax=cax, zorder=5)
fig.savefig('HurtoP 2020.jpg')

# %%
# Control del tamaño de la figura del mapa
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
 
# Control del encuadre (área geográfica) del mapa
#ax.axis([-12, 5, 32, 48])
 
# Control del título y los ejes
ax.set_title('HURTO A PERSONAS  2021', 
             pad = 20, 
             fontdict={'fontsize':20, 'color': '#4873ab'})

 
# Añadir la leyenda separada del mapa
from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.2)
 
# Generar y cargar el mapa
map_BO.plot(column='CMHP21CONT', cmap='winter', ax=ax,
              legend=True, cax=cax, zorder=5)
fig.savefig('HurtoP 2022.jpg')
